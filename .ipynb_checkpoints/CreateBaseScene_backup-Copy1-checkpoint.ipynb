# %%
import sys
sys.path.append('../Monet')
import xx

# %% [markdown]
# ## Workflow

# %%
w = xx.workflow()
#w.append("010.unreal.open_content_drawer.png")
# create DarkGrid
w.append("020.unreal.add_content.png")
w.append("030.unreal.create_material.png")
w.append("040.unreal.generate_DarkGrid_mat.png")
w.append("050.unreal.material_connections.png")
w.append("060.unreal.material_doublesided.png")
w.append("070.unreal.popup.png")
# create BlackBg 
w.append("020.unreal.add_content.png")
w.append("080.unreal.create_material.png")
w.append("090.unreal.material_connections.png")
w.append("070.unreal.popup.png")
# create GlowingGrid
w.append("020.unreal.add_content.png")
w.append("100.unreal.create_material.png")
w.append("110.unreal.translucent_material.png")
w.append("120.unreal.material_connections.png")
# create geometry in the scene
# Out:
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded

# %%
w.run()
# Out:
# locating (0/10):
# -> Image Found @: Box(left=13, top=1070, width=202, height=79)
#     -> Clicked @: [77,1130]
# locating (0/10):
# -> Image Found @: Box(left=167, top=1289, width=180, height=56)
#     -> running python
#     --> Clicked @: [203,1319]
#     --> type: 'DarkGrid'
#     --> type: [enter]+[enter]
# locating (0/10):
# locating (1/10):
# -> Image Found @: Box(left=1048, top=326, width=287, height=126)
#     -> running python1
#     --> moved @: [1808,724]
#     --> zoom: -5
#     -> running python2
#     --> moved @: [998,726]
#     --> typed: [ctrl]+[v]
# locating (0/10):
# locating (1/10):
# locating (2/10):
# locating (3/10):
# locating (4/10):
# locating (5/10):
# locating (6/10):
# -> Image Found @: Box(left=1344, top=569, width=334, height=383)
#     -> Clicked @: [1467,622]
#     -> Clicked @: [1525,1038]
#     -> Clicked @: [1435,748]
#     -> Clicked @: [1498,1005]
#     -> Clicked @: [1483,920]
#     -> Clicked @: [1538,1240]
#     -> Clicked @: [1508,792]
# ...

# %% [markdown]
# ## Sand box

# %%
step1 = xx.step()

# %%
step1.capture()
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [r]    - recapture image with previous location, ie no mouse highlight
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
# -> gui.screenshot(region=(1630,154,394,84))
# -> _markers.append(218,205,'click',''))
# -> _markers.append(177,140,'click',''))
#     Scripts copied

# %%
step1.paste()
# Out:
# No pre script....
# loc=[[218,205,'python1',''],[177,140,'click',''],[0,0,'python2','']]
# keywords = []
# if self.found_loc==None:
#     print("-> Image Not Found")
# else:
#     print("-> Image Found @: "+str(self.found_loc))
#     for location in loc:
#         abs_location = [self.found_loc.left+location[0], self.found_loc.top+location[1]]
#         if location[2] == 'click':
#             time.sleep(self.ui_delay)
#             gui.click(abs_location[0], abs_location[1])
#             print("    -> Clicked @: ["+str(abs_location[0])+","+str(abs_location[1])+"]")
#         if location[2] == 'type':
#             try:
#                 text = location[3]
#             except:
#                 text = ""
#
#             time.sleep(self.ui_delay)
#             gui.hotkey('ctrl','a')
#             time.sleep(self.ui_delay)
#             gui.click(abs_location[0], abs_location[1])
#             time.sleep(self.ui_delay)
#             gui.typewrite(text)
# ...

# %%
step1.savePNG("130.unreal.add_geom.png")

# %%
step1.run()
# Out:
# locating (0/10):
# -> Image Found @: Box(left=1630, top=154, width=394, height=84)
#     -> running python1
#     --> clicked @: [1848,359]
#     --> typed: [home]
#     -> Clicked @: [1807,294]
#     -> running python2
#     --> typed: [ctrl]+[v]

# %%
testW = xx.workflow()
testW.append("020.unreal.add_content.png")
testW.append("100.unreal.create_material.png")
testW.append("110.unreal.translucent_material.png")
testW.append("120.unreal.material_connections.png")
# Out:
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded

# %%
testW.run()
# Out:
# locating (0/10):
# -> Image Found @: Box(left=13, top=1072, width=202, height=79)
#     -> Clicked @: [77,1132]
# locating (0/10):
# -> Image Found @: Box(left=167, top=1289, width=180, height=56)
#     -> running python
#     --> Clicked @: [203,1319]
#     --> type: 'GlowingGrid'
#     --> type: [enter]+[enter]
# locating (0/10):
# locating (1/10):
# -> Image Found @: Box(left=1061, top=317, width=274, height=172)
#     -> Clicked @: [246,1121]
#     -> Clicked @: [228,1207]
#     -> Clicked @: [197,1202]
#     -> running python1
#     --> moved @: [1861,717]
#     --> zoom: -5
#     -> running python2
#     --> moved @: [1011,717]
#     --> typed: [ctrl]+[v]
# locating (0/10):
# locating (1/10):
# -> Image Found @: Box(left=1389, top=482, width=286, height=387)
#     -> Clicked @: [1524,522]
#     -> Clicked @: [1626,774]
#     -> Clicked @: [1522,525]
#     -> Clicked @: [1578,1100]
#     -> Clicked @: [1544,829]
#     -> Clicked @: [1608,1207]

# %%
step2 = xx.step("040.unreal.generate_DarkGrid_mat.png")
# Out:
# Image sucessfully loaded

# %%
step2.copy()
# Out:
#     Scripts copied

# %%
step2.copy()
# Out:
#     Scripts copied

# %%
step2.savePNG("030.unreal.create_material.png")
