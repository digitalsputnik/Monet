# %%
import xx2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/rubicon/objc/ctypes_patch.py:21: UserWarning: rubicon.objc.ctypes_patch has only been tested with Python 3.4 through 3.10. You are using Python 3.11.0. Most likely things will work properly, but you may experience crashes if Python's internals have changed significantly.
#   warnings.warn(

# %% [markdown]
# restore png from disk with specific name

# %%
w = xx2.workflow("get_unreal_filename")

# %%
w.add_step()
w.last_step().capture_action_marker()
# Out:
# [!] Capture image 1st before assiging a marker
# Capture images and (input) positions for step construction
# [command]  - mark image corner (top left to right bottom)
# [esc]  - stop capture
#
#  -> saved location on screen: 26 , 881
#  -> saved location on screen: 141 , 907
#  -> captured:
# locating (0/10):
# found @: [26, 881, 115, 26]
# Image found @: 26, 881
# [command]  - mark action location
# [esc]  - stop capture
#
#  -> saved location on screen: 62 , 892
#  -> captured action marker @: 36, 11

# %%
#w.add_step()
w.last_step().pre_script_str="gui.hotkey(os_ctrl(),'c')\nxx=pyperclip.paste()\nprint(xx.split('.uproject')[0].split('/')[-1])"

# %%
w.copy_step()
w.last_step().capture_action_marker()
w.last_step().edit()
# Out:
# locating (0/10):
# found @: [3, 1300, 238, 26]
# Image found @: 3, 1300
# [command]  - mark action location
# [esc]  - stop capture
#
#  -> saved location on screen: 69 , 1084
#  -> captured action marker @: 66, -216
#  -> overwriting offset_x
#  -> overwriting offset_y
#  -> overwriting mouse
#  -> overwriting ctrla
#  -> overwriting text
#  -> overwriting enter
# Text(value='3', description='x')
# Text(value='1300', description='y')
# Text(value='238', description='width')
# Text(value='26', description='height')
# Checkbox(value=True, description='break if not found')
# Text(value='66', description='offset_x')
# Text(value='-216', description='offset_y')
# Dropdown(description='mouse', index=1, options=('move', 'click', 'right-click', 'double-click'), value='click'…
# Checkbox(value=False, description='ctrla')
# Text(value='', description='text')
# Checkbox(value=False, description='enter')
# [!] clear output before sving the step

# %%
w.save()
# Out:
# load step: step = xx2.step(name="get_unreal_filename/e00cd517-324f-437a-8b74-9afd1ad1501b")
# load step: step = xx2.step(name="get_unreal_filename/5e0e042f-b5ce-40cc-8d25-1fdc1b633b17")
# load step: step = xx2.step(name="get_unreal_filename/9fb330b7-1c6d-4075-bdf5-7a4fad390e05")
# load step: step = xx2.step(name="get_unreal_filename/815ef667-1d48-4151-8b20-3cbed75823cf")
# [!] Capture image 1st before exporting, nothing to export yet...

# %%
w.run()
# Out:
# locating (0/30):
# found @: [3, 1300, 238, 26]
#  -> clicked @: [179,1315]
# locating (0/30):
# found @: [3, 1300, 238, 26]
#  -> clicked @: [70,892]
#  -> Pasted : .uproject"
# locating (0/30):
# found @: [3, 1300, 238, 26]
#  -> right-clicked @: [69,1084]
# locating (0/30):
# found @: [82, 1055, 83, 17]
#  -> clicked @: [120,1065]
# init_osx_pyobjc_clipboard.<locals>.copy_osx_pyobjc() missing 1 required positional argument: 'text'

# %%
import time

w.run()
w.add_step()
w.last_step().capture_region()
time.sleep(3)
w.last_step().recapture_region()
# Out:
# locating (0/30):
# found @: [3, 1300, 238, 26]
#  -> clicked @: [179,1315]
# locating (0/30):
# found @: [3, 1300, 238, 26]
#  -> clicked @: [70,892]
#  -> Pasted : .uproject"
# locating (0/30):
# found @: [3, 1300, 238, 26]
#  -> right-clicked @: [69,1084]
# Capture images and (input) positions for step construction
# [command]  - mark image corner (top left to right bottom)
# [esc]  - stop capture
#
#  -> saved location on screen: 82 , 1055
#  -> saved location on screen: 165 , 1072
#  -> captured:

# %%
import pyperclip
xx=pyperclip.paste()\nxx.split('.uproject"')[0].split('/')[-1]
# Out:
# 'visualtest'

# %%
w.copy_step()

# %%
w.save()
# Out:
# load step: step = xx2.step(name="test_wf/ed8f9d1a-daef-40dc-8684-be645ffd16b0")

# %%
y = xx2.workflow("test_wf")
y.load()
y.run()
# Out:
#  -> Payload loaded, overwritng self
# locating (0/30):
# found @: [352, 280, 203, 33]
#  -> clicked @: [382,334]
#  -> Keystroke: [ctrl]+[a]
#  -> Pasted : xxx

# %%
import os
os.makedirs("testx")

# %%
xx2.test = xx2.step()

# %%
xx2.test.name = "mytest1"

# %%
xx2.test.capture_action_marker()

# %%
xx2.test.loadPNG()

# %%
xx2.test.savePNG()

# %%
a = xx2.step(name='mytest1')

# %%
a.__dict__

# %%
step = xx2.step(name="mytest1")

# %%
step.__dict__

# %%
step.__dict__ = {'name': 'mytest1', '_img': <PIL.Image.Image image mode=RGBA size=508x48 at 0x1055D90D0>, 'timeout': 30, 'wait': 1, 'scroll': False, 'ui_delay': 0.1, 'pre_script_str': '', 'payload_str': '', '_properties': ['x':'314' (custom callbacks), 'y':'250' (custom callbacks), 'width':'254' (custom callbacks), 'height':'24' (custom callbacks), 'break if not found':'True' (custom callbacks), 'offset_x':'90' (custom callbacks), 'offset_y':'9' (custom callbacks), 'mouse':'click' (custom callbacks), 'ctrla':'False' (custom callbacks), 'text':'' (custom callbacks), 'enter':'False' (custom callbacks)], '_action_img': None}

# %% [markdown]
# test

# %%
xx2.test.__dict__

# %%
p.steps[0].__dict__

# %%
step = xx2.step(name="mytest1")

# %%
step.run()

# %% [markdown]
# create a new step as a copy

# %%
test=xx2.step()
test.name = "mytest1"
test.loadPNG()

# %%
import copy
test2=copy.copy(test)

# %%
test2.capture_action_marker()

# %%
test.run()
test2.run()

# %%
test.

# %%
test = xx2.step()

# %%
test.capture_action_marker()

# %%
test.savePNG()

# %% [markdown]
# ### Prop Tests

# %%
test = xx2.prop("x",False,init_script={'init':xx2.create_checkbox_str,'edit':xx2.edit_str,'draw':xx2.draw_str})

# %%
test.draw()

# %%
test.value = True

# %%
xx2.test.get_prop("x")

# %%
import shutil

# %%
with open("test_wf/test_wf.pickle", "r") as file:
    data = file.read()
print(data)
