# %%
import xx
w = xx.workflow()
w.load_folder(".")

# add step 0 in the second loaction 
w.steps.insert(5,w.steps[0])
# Out:
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded
# Image sucessfully loaded

# %%
w.run()
# Out:
# locating (0/10):
# locating (0/10):
# locating (0/10):
# locating (1/10):
# locating (0/10):
# locating (0/10):
# locating (0/10):
# locating (0/10):
# locating (0/10):
# locating (1/10):
# locating (0/10):
# locating (0/10):
# locating (1/10):
# locating (2/10):
# locating (3/10):
# locating (4/10):
# locating (5/10):
# locating (6/10):
# locating (7/10):
# locating (8/10):
