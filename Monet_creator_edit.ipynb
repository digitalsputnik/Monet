# %%
import xx
import time
import pyautogui as gui
import copy

# %% [markdown]
# # Step 1
# Switch to Unreal Engine (make sure there is a new clean project open)
# ![image.png](attachment:0bd8679a-4ea5-420d-b980-520b3b75d4b5.png)

# %% [markdown]
# ## 1. Create a new step
# Every workflow contains of steps, every step is one image to found from screen.
# Capture the image to be found (NB! Make sure it is unique area of the screen, ie appears only once)
# Add location(s) where to click, where to type or run a custom python script

# %%
step1 = xx.step()
step1.capture()

# %%
# or load it from file
step1.loadPNG("1.unreal.content_drawer.png")
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 12,1152
#  -> pos: 204,1189
# loc=[[101,17]]

# %% [markdown]
# ## 2. Edit code or add actions

# %%
step1.paste()
step1.savePNG("1.unreal.content_drawer.png")

# %% [markdown]
# ## 3. Test current step(s)
# If necessary make the logic here how to test the current step, sometimes it is necessary test more than one step at a time

# %%
step1.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=192x37 at 0x1E74CADFC70> try 0

# %% [markdown]
# ### 3.1 Reset test
# Remove the items generated on set back context before testing so You could try again!

# %%
pass

# %% [markdown]
# # Step 2
# Open Content Drawer
#
# <img src="attachment:cc97a2c6-a204-4e1b-99f4-9477fad06030.png" width="500"/>

# %%
step2 = xx.step()

# %%
step2.capture()
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 42,758
#  -> pos: 400,792
# loc=[[58,22],[61,18]]

# %%
step2.copy()
# Out:
#     Scripts copied

# %%
step2.paste()
step2.savePNG("2.unreal.add_content.png")
# Out:
# No pre script....
# loc=[[58,22]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     time.sleep(0.2)
#     gui.click(abs_loc[0], abs_loc[1])
#     time.sleep(0.2)
#     gui.hotkey('space')
#     time.sleep(0.2)
#     gui.typewrite('interface')
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step2.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=358x34 at 0x1E74D122E00> try 0

# %%
step3 = xx.step()

# %%
step2.run()
step3.capture()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=116x40 at 0x1E74CD2AE30> try 0
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 83,982
#  -> pos: 401,1047
# loc=[[118,30],[83,31]]

# %%
step3.copy()
# Out:
#     Scripts copied

# %%
step3.paste()
step3.savePNG("3.unreal.editor_utility_blueprint.png")
# Out:
# No pre script....
# loc=[[118,30]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     time.sleep(0.2)
#     gui.click(abs_loc[0], abs_loc[1])
#     time.sleep(0.2)
#     gui.typewrite('BPI_EditorTick')
#     time.sleep(0.2)
#     gui.press('enter')
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step2.run()
step3.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=116x40 at 0x1E74CD2AE30> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=318x65 at 0x1E74CBA6440> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=318x65 at 0x1E74CBA6440> try 1

# %%
step4 = xx.step()

# %%
step4.capture()
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 1176,930
#  -> pos: 1303,1052
# loc=[[54,57]]

# %%
step4.copy()
# Out:
#     Scripts copied

# %%
step4.paste()
step4.savePNG("4.unreal.open_editor.png")
# Out:
# No pre script....
# loc=[[54,57]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     time.sleep(0.2)
#     gui.doubleClick(abs_loc[0], abs_loc[1])
#     time.sleep(0.2)
#     gui.typewrite('EditorTick')
#     gui.press('enter')
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step4.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 0

# %%
step4.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 0

# %%
step5 = xx.step()

# %%
step5.capture()
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 1595,951
#  -> pos: 1792,993
# loc=[[262,19],[176,20]]

# %%
step5.copy()
# Out:
#     Scripts copied

# %%
step5.paste()
step5.savePNG("5.unreal.call_in_editor.png")
# Out:
# Pre script:
# myApp = gui.getWindowsWithTitle("BPI_EditorTick")[0]
# myApp.restore()
# time.sleep(0.2)
# myApp.topleft = gui.Point(0,0)
# myApp.width = 1920
# myApp.height = 1200
# loc=[[176,20]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     time.sleep(0.2)
#     gui.click(abs_loc[0], abs_loc[1])
#     time.sleep(0.2)
#     gui.hotkey('F7')
#     time.sleep(0.2)
#     gui.hotkey('alt','F4')
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step5.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=197x42 at 0x1E74F1366B0> try 0

# %%
# create editor tick
step1.run()
step2.run()
step3.run()
step4.run()
step5.run()
# create editor utilty
step1.run()

# create shaders

# create objectrs
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=192x37 at 0x1E74CADFC70> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=358x34 at 0x1E74D122E00> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=318x65 at 0x1E74CBA6440> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=318x65 at 0x1E74CBA6440> try 1
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 1
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 2
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 3
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 4
# trying to locate img: <PIL.Image.Image image mode=RGB size=127x122 at 0x1E74CBA6AD0> try 5
# ...

# %%
step1.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=192x37 at 0x1E74CADFC70> try 0

# %%
step8 = copy.copy(step7)

# %%
step6.copy()
# Out:
#     Scripts copied

# %%
step6.paste()
# Out:
# No pre script....
# loc=[[58,17]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     gui.click(abs_loc[0], abs_loc[1])
#     gui.hotkey('space')
#     gui.typewrite('utility')
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step6.savePNG("6.unreal.add_editor_iterface.png")

# %%
step7.capture()
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 83,864
#  -> pos: 390,928
# loc=[[118,30],[83,31],[35,28]]

# %%
step7.paste()
# Out:
# No pre script....
# loc=[[35,28]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     gui.click(abs_loc[0], abs_loc[1])
#     time.sleep(1)
#     gui.typewrite('editorutilityactor')
#     gui.press('down')
#     gui.press('down')
#     gui.press('enter')
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step7.savePNG("7.unreal.select_editor_iterface_class.png")

# %%
step8.capture()
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 2254,1148
#  -> pos: 2504,1200
# loc=[[118,30],[83,31],[35,28],[67,34]]

# %%
step8.paste()
# Out:
# No pre script....
# loc=[[67,34]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     gui.click(abs_loc[0], abs_loc[1])
#     gui.typewrite('BP_EditorTicker')
#     gui.press('enter')
#     gui.press('enter')
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step8.savePNG("8.unreal.select.png")

# %%
step1.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=192x37 at 0x1E74CADFC70> try 0

# %%
step8 = xx.step()

# %%
step8.capture()
# Out:
# Capture images and (input) positions for step construction
# [alt]  - mark image corner (top left to right bottom)
# [w]    - show captured image
# [m]    - add click or input marker, print variable as string
# [q]    - stop capture
#  -> pos: 1447,254
#  -> pos: 1542,489
# loc=[[12,180]]
# loc=[[12,180],[272,59]]
# loc=[[12,180],[272,59],[273,220]]

# %%
step8.loadPNG("8.unreal.select.png")
# Out:
# #pre script
#
# #script
# loc=[[67,34]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     gui.click(abs_loc[0], abs_loc[1])
#     gui.typewrite('BP_EditorTicker')
#     gui.press('enter')
#     gui.press('enter')
# Image sucessfully loaded

# %%
step9 = copy.copy(step8)

# %%
# Out:
# No pre script....
# loc=[[67,34]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     gui.click(abs_loc[0], abs_loc[1])
#     gui.typewrite('BP_EditorTicker')
#     gui.press('enter')
#     gui.press('enter')
#
# ##Step9
# #pre script
#
# #script
# loc=[[12,180],[272,59],[273,220]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc1 = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     abs_loc2 = [found[0]+loc[1][0], found[1]+loc[1][1]]
#     abs_loc3 = [found[0]+loc[2][0], found[1]+loc[2][1]]
#     gui.click(abs_loc1[0], abs_loc1[1])
#     time.sleep(0.2)
#     gui.click(abs_loc2[0], abs_loc2[1])
#     time.sleep(0.2)
#     gui.click(abs_loc3[0], abs_loc3[1])
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ...

# %%
step9.paste()
step9.savePNG("9.unreal.class_editor_ticking.png")
# Out:
# No pre script....
# loc=[[12,180],[272,59],[273,220]]
# if self.found_loc==None:
#     print("  Image Not Found")
# else:
#     found = [self.found_loc.left,self.found_loc.top]
#     abs_loc1 = [found[0]+loc[0][0], found[1]+loc[0][1]]
#     abs_loc2 = [found[0]+loc[1][0], found[1]+loc[1][1]]
#     abs_loc3 = [found[0]+loc[2][0], found[1]+loc[2][1]]
#     time.sleep(0.2)
#     gui.click(abs_loc1[0], abs_loc1[1])
#     time.sleep(0.2)
#     gui.click(abs_loc2[0], abs_loc2[1])
#     time.sleep(0.2)
#     gui.click(abs_loc3[0], abs_loc3[1])
# --------------------------- Update scripts? ---------------------------
# 0 [0] Keep
# 1 [1] Cancel
# ---------------------------------- -- ----------------------------------
# 1(Cancel):  0
#     Scripts updated

# %%
step1.run()
step6.run()
step7.run()
step8.run()
step9.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=192x37 at 0x1E74CADFC70> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=358x34 at 0x1E74D122E00> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=307x64 at 0x1E74F137970> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=307x64 at 0x1E74F137970> try 1
# trying to locate img: <PIL.PngImagePlugin.PngImageFile image mode=RGB size=250x52 at 0x1E74F4F3B50> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=95x235 at 0x1E74F142CE0> try 0
# trying to locate img: <PIL.Image.Image image mode=RGB size=95x235 at 0x1E74F142CE0> try 1

# %%
step9.run()
# Out:
# trying to locate img: <PIL.Image.Image image mode=RGB size=95x235 at 0x1E74F142CE0> try 0

# %%
step9._img
# Out:
# <PIL.Image.Image image mode=RGB size=95x235>

# %%
gui.
