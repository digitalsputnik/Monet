# %% [markdown]
# The Plan
# - [ ] run unreal 5.0.3
# - [ ] create a new scene (media, raytracing enabled)
# - [ ] run epic...
# - [x] add to project
# 1. Brushify scene
# 1. Abstract object
# 1. the dude
# - [x] switch to unreal
# - [ ] open level
# - [ ] place the abstract
# - [ ] place the manequin
# - [ ] add ticker
# - [ ] add DSDM for live tweaking
# - [ ] Play, Pause button?

# %%
import xx2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/rubicon/objc/ctypes_patch.py:21: UserWarning: rubicon.objc.ctypes_patch has only been tested with Python 3.4 through 3.10. You are using Python 3.11.0. Most likely things will work properly, but you may experience crashes if Python's internals have changed significantly.
#   warnings.warn(

# %% [markdown]
# ## Import Workflows

# %%
ground_assets = xx2.workflow("ue_add_asset_Skybox_Bundle_II")
manneq_assets = xx2.workflow("ue_add_asset_ODSMannequin")
fracta_assets = xx2.workflow("ue_add_asset_UCreate")

ue_scene = xx2.workflow("ue_assemmble_scene")

ground_assets.load()
manneq_assets.load()
fracta_assets.load()
ue_scene.load()
# Out:
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self
#  -> Payload loaded, overwritng self

# %%
ground_assets.show_steps()

# %% [markdown]
# ## Run Workflows

# %% [markdown]
# ### Import Assets

# %%
ground_assets.run()
manneq_assets.run()
fracta_assets.run()
ue_scene.run()
# Out:
# locating (0/30):
# found @: [21, 74, 56, 247]
#  -> clicked @: [18,143]
# locating (0/30):
# found @: [21, 74, 56, 247]
#  -> clicked @: [50,304]
# locating (0/30):
# found @: [558, 64, 102, 71]
#  -> clicked @: [608,103]
# locating (0/30):
# found @: [635, 459, 209, 56]
#  -> clicked @: [699,490]
#  -> Pasted : xxx
# locating (0/30):
# locating (1/30):
# found @: [638, 710, 174, 53]
#  -> clicked @: [700,735]
#  -> Pasted : Skybox Bundle
# locating (0/30):
# found @: [370, 824, 163, 33]
#  -> clicked @: [431,842]
# locating (0/30):
# found @: [220, 414, 128, 32]
#  -> clicked @: [251,435]
#  -> Pasted : atest
# locating (0/30):
# found @: [246, 375, 99, 33]
#  -> clicked @: [290,529]
# locating (0/30):
# found @: [468, 842, 178, 38]
#  -> clicked @: [555,869]
# locating (0/30):
# found @: [250, 672, 77, 24]
#  -> clicked @: [667,737]
# locating (0/30):
# found @: [252, 420, 143, 30]
#  -> clicked @: [669,492]
# locating (0/30):
# found @: [21, 74, 56, 247]
#  -> clicked @: [18,143]
# locating (0/30):
# found @: [21, 74, 56, 247]
#  -> clicked @: [50,304]
# locating (0/30):
# locating (1/30):
# found @: [558, 64, 102, 71]
#  -> clicked @: [608,103]
# locating (0/30):
# found @: [634, 460, 209, 56]
#  -> clicked @: [698,491]
#  -> Pasted : xxx
# locating (0/30):
# locating (1/30):
# found @: [638, 710, 174, 53]
#  -> clicked @: [700,735]
#  -> Pasted : Military Style
# locating (0/30):
# found @: [370, 824, 163, 33]
#  -> clicked @: [431,842]
# locating (0/30):
# found @: [220, 414, 128, 32]
#  -> clicked @: [251,435]
#  -> Pasted : atest
# locating (0/30):
# found @: [246, 375, 99, 33]
#  -> clicked @: [290,529]
# locating (0/30):
# found @: [468, 842, 178, 38]
#  -> clicked @: [555,869]
# locating (0/30):
# found @: [250, 672, 77, 24]
#  -> clicked @: [667,737]
# locating (0/30):
# found @: [252, 420, 143, 30]
#  -> clicked @: [669,492]
# locating (0/30):
# found @: [21, 74, 56, 247]
#  -> clicked @: [18,143]
# locating (0/30):
# found @: [21, 74, 56, 247]
#  -> clicked @: [50,304]
# locating (0/30):
# locating (1/30):
# found @: [558, 64, 102, 71]
#  -> clicked @: [608,103]
# locating (0/30):
# found @: [635, 460, 209, 56]
#  -> clicked @: [699,491]
#  -> Pasted : xxx
# locating (0/30):
# locating (1/30):
# found @: [638, 710, 174, 53]
#  -> clicked @: [700,735]
#  -> Pasted : UCreate
# locating (0/30):
# found @: [370, 824, 163, 33]
#  -> clicked @: [431,842]
# locating (0/30):
# found @: [220, 414, 128, 32]
#  -> clicked @: [251,435]
#  -> Pasted : atest
# locating (0/30):
# found @: [246, 375, 99, 33]
#  -> clicked @: [290,529]
# locating (0/30):
# found @: [468, 842, 178, 38]
#  -> clicked @: [555,869]
# locating (0/30):
# found @: [250, 672, 77, 24]
#  -> clicked @: [667,737]
# locating (0/30):
# found @: [252, 420, 143, 30]
#  -> clicked @: [669,492]
# locating (0/30):
# found @: [94, 1298, 234, 26]
#  -> clicked @: [752,1317]
# locating (0/30):
# locating (1/30):
# locating (2/30):
# locating (3/30):
# locating (4/30):
# locating (5/30):
# found @: [204, 894, 38, 59]
#  -> clicked @: [219,939]
# locating (0/30):
# locating (1/30):
# locating (2/30):
# locating (3/30):
# locating (4/30):
# found @: [197, 894, 40, 57]
#  -> clicked @: [140,965]
#  -> Pasted : skybox
# locating (0/30):
# locating (1/30):
# found @: [93, 979, 131, 102]
#  -> clicked @: [185,1059]
# locating (0/30):
# found @: [249, 1162, 108, 33]
#  -> double-clicked @: [367,1055]
#  -> Keystroke: [enter]
# locating (0/30):
# locating (1/30):
# locating (2/30):
# locating (3/30):
# found @: [1062, 204, 168, 42]
#  -> clicked @: [1115,464]
# locating (0/30):
# found @: [494, 78, 151, 33]
#  -> Offsets not found
# True
# [!] Image not found, breaking flow!
